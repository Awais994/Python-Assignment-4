# %% [markdown]
# # 1. Make a calculator using Python with addition , subtraction , multiplication ,division and power.

# %%
inp1 = input("First number:")
inp2 = input("Operator:")
inp3 = input("Last number:")
new_input = inp1 + inp2 + inp3
if inp2 == "*":
    print(int(inp1) * int(inp3))
elif inp2 == "+":
    print(int(inp1) + int(inp3))
elif inp2 == "-":
    print(int(inp1) - int(inp3))
elif inp2 == "/":
    print(int(inp1) / int(inp3))
elif inp2 == "**":
    print(int(inp1) ** int(inp3))
# Out:
# First number:4
# Operator:*
# Last number:4
# 16

# %% [markdown]
# # 2. Write a program to check if there is any numeric value in list using for loop.

# %%
lst1 = ["a","b","c","d",1,2,3,4]
for i in lst:
     if isinstance(i, int):
            print(i)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# # 3. Write a Python script to add a key to a dictionary.

# %%
dict = {'key1':'New', 'key2':'Name'}
print("Current Dict is: ", dict)
dict['key3'] = 'Is'
print("Updated Dict is: ", dict)
# Out:
# Current Dict is:  {'key1': 'New', 'key2': 'Name'}
# Updated Dict is:  {'key1': 'New', 'key2': 'Name', 'key3': 'Is'}

# %% [markdown]
# # 4. Write a Python program to sum all the numeric items in a dictionary.

# %%
dic = {"a":2,"b": 4, "c":5,"d":6} 
num = sum(dic.values())
print(f"The sum of Dictionary is: {num}")
# Out:
# The sum of Dictionary is: 17

# %% [markdown]
# # 5. Write a program to identify duplicate values from list.

# %%
lst1 = [1,5,2,5,1,7]
lst2 = []
for i in lst1:
    if i not in lst2:
        lst2.append(i)
    else:
        print(i)
# Out:
# 5
# 1

# %% [markdown]
# # 6. Write a Python script to check if a given key already exists in a dictionary

# %%
dic = {"a": 1,"b":2,"c":3,"d": 4}
user_input= input("Enter the key:")
if user_input in dic:
    print("The given key is already exsit")
    print(f"The key name is : {user_input}")
else:
    print("Sorry This key does not exsit")
# Out:
# Enter the key:a
# The given key is already exsit
# The key name is : a
